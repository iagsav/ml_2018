# %% [markdown]
# # Лабораторная 1
#
# ## Предварительная обработка данных
#
# ### Выполнил студент группы 16-В-1 Мишанов Фёдор
#
# <b>Цель лабораторной работы</b>: получение навыков работы с библиотеками анализа данных, предварительной обработки данных, средствами визуализации. <b>Задание</b>: 7 вариант - Камеры:
#
# 1. Визуализируйте корреляции между признаками, находящимися в наборе данных (heatmap). Сделайте выводы.
# 2. Вычислите корреляцию Пирсона и Спирмена между Price и Max (Min) Resolution. Сравните полученные величины корреляции. Постройте гистограммы для указанных признаков. Оцените значение p-value.
# 4. Постройте график изменения средней цены на камеры по годам.
# 5. Определите компанию, камеры которой наиболее часто встречаются в наборе данных.
# 6. Добавьте в набор данных признак, являющийся произведением двух других признаков.
# 7. Удалите строки с нулевыми значениями в данных. Выведите размер набора данных до и после удаления.
# 8. Определите камеру с максимальной стоимостью, определите камеру с минимальной стоимостью.
# 9. Определите год, в который было выпущено максимально количество новых камер.

# %%
import Lab1Module as lb1
worker=lb1.Lab1Worker("./camera_dataset.csv")
worker.data
# Out:
# File reading OK
# Required columns OK
#                        Model  Release date  Max resolution  Low resolution  \
# 1           Agfa ePhoto 1280        1997.0          1024.0           640.0
# 2           Agfa ePhoto 1680        1998.0          1280.0           640.0
# 3           Agfa ePhoto CL18        2000.0           640.0             0.0
# 4           Agfa ePhoto CL30        1999.0          1152.0           640.0
# 5     Agfa ePhoto CL30 Clik!        1999.0          1152.0           640.0
# 6           Agfa ePhoto CL45        2001.0          1600.0           640.0
# 7           Agfa ePhoto CL50        1999.0          1280.0           640.0
# 8        Canon PowerShot 350        1997.0           640.0             0.0
# 9        Canon PowerShot 600        1996.0           832.0           640.0
# 10       Canon PowerShot A10        2001.0          1280.0          1024.0
# 11      Canon PowerShot A100        2002.0          1280.0          1024.0
# ...

# %% [markdown]
# #### Задание 1: Удалите строки с нулевыми значениями в данных. Выведите размер набора данных до и после удаления.

# %%
string="Количество записей {0} удаления: {1}"
s1=string.format("до",worker.records_count())
print(s1)
worker.remove_zeroes()
s1=string.format("после",worker.records_count())
print(s1)
# Out:
# Количество записей до удаления: 1038
# Количество записей после удаления: 785

# %% [markdown]
# #### Задание 2: Визуализируйте корреляции между признаками, находящимися в наборе данных (heatmap). Сделайте выводы.
# Для визуализации используется модуль <b>seaborn</b>, облегчающий построение таких таблиц. Таблица представляет из себя зависимость <b>цены</b> и <b>разрешения</b> камер за данный период:

# %%
worker.heatmap()

# %% [markdown]
# Из таблицы можно увидеть, сколько камер с какой разрешающей способностью было выпущено в каком году.
#
# Можно сделать вывод, что со временем разрешающая способность камер растёт, а их цена снижается, но при этом цена растёт по нарастающей в зависимости от разрешающей способности.
#
# #### Задание 3: Вычислите корреляцию Пирсона и Спирмена между Price и Max (Min) Resolution. Сравните полученные величины корреляции. Постройте гистограммы для указанных признаков. Оцените значение p-value.

# %%
string="Критерий {0}: {1} P-value: {2}"
k,p = worker.pearsonr()
print(string.format("Пирсона",k,p))
k,p = worker.spearmanr()
print(string.format("Спирмана",k,p))
# Out:
# Критерий Пирсона: -0.08527950702178304 P-value: 0.016853145440149094
# Критерий Спирмана: -0.014906147626522174 P-value: 0.6766814208853782

# %% [markdown]
# При сравнении видно, что результаты различаются, но на небольшое значение. P-значение в случае с Пирсоном низкое, что говорит о том, что нулевая гипотеза - переменные линейно независимы - отвергается. Так как критерий отрицателен, то можно сказать, что величины обратно зависимы, т.е. чем выше значение одной переменной, тем ниже значение другой.
#
# Гистограмма цены:

# %%
worker.priceplot()
# Out:
# C:\Users\Whispershine\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Гистограмма для максимального разрешения

# %%
worker.resplot()
# Out:
# C:\Users\Whispershine\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Задание 4: Постройте график изменения средней цены на камеры по годам

# %%
worker.price_by_year()

# %% [markdown]
# #### Задание 5: Определите компанию, камеры которой наиболее часто встречаются в наборе данных.

# %%
string="Самая часто встречающаяся компания: {0}, {1} записей"
firm,count = worker.most_present_firm()
print(string.format(firm,count))
# Out:
# Самая часто встречающаяся компания: Olympus, 102 записей

# %% [markdown]
# #### Задание 6: Добавьте в набор данных признак, являющийся произведением двух других признаков.

# %%
worker.add_multiply_column("Useless zoom mult","Zoom wide (W)","Zoom tele (T)")
worker.data
# Out:
#                         Model  Release date  Max resolution  Low resolution  \
# 2            Agfa ePhoto 1680        1998.0          1280.0           640.0
# 6            Agfa ePhoto CL45        2001.0          1600.0           640.0
# 10        Canon PowerShot A10        2001.0          1280.0          1024.0
# 11       Canon PowerShot A100        2002.0          1280.0          1024.0
# 12        Canon PowerShot A20        2001.0          1600.0          1024.0
# 13       Canon PowerShot A200        2002.0          1600.0          1024.0
# 14        Canon PowerShot A30        2002.0          1280.0          1024.0
# 15       Canon PowerShot A300        2003.0          2048.0          1600.0
# 17        Canon PowerShot A40        2002.0          1600.0          1024.0
# 20       Canon PowerShot A420        2006.0          2272.0          1600.0
# 21       Canon PowerShot A430        2006.0          2272.0          1600.0
# ...

# %% [markdown]
# #### Задание 7: Определите камеру с максимальной стоимостью, определите камеру с минимальной стоимостью.
# Максимальная стоимость

# %%
worker.max_price_items()
# Out:
#                 Model  Release date   Price
# 826  Ricoh GR Digital        2005.0  4999.0
# 835    Ricoh RDC-i500        2001.0  4999.0

# %% [markdown]
# Минимальная стоимость

# %%
worker.min_price_items()
# Out:
#             Model  Release date  Price
# 348  JVC GC-QX3HD        2001.0   14.0
# 349  JVC GC-QX5HD        2001.0   14.0

# %% [markdown]
# #### Задание 8: Определите год, в который было выпущено максимально количество новых камер.

# %%
worker.max_new_models()
# Out:
# (2007.0, 130)

# %% [markdown]
# Ответ: 2007 год, 130 моделей
