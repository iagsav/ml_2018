# %%
import pandas as pd
df = pd.read_csv ("C:/Users/Na_stole_64/Desktop/Jupiter_lab/cneos_fireball_data.csv")
df.head()
# Out:
#   Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0            2017-07-31 22:01:35           24.7N           118.5W
# 1            2017-07-23 06:12:38            6.6S            69.7W
# 2            2017-07-13 09:30:36           23.1N            60.7E
# 3            2017-06-30 14:26:45           34.3S           134.5E
# 4            2017-06-23 20:21:55           57.0N           143.7E
#
#    Altitude (km)  Velocity (km/s)    vx    vy    vz  \
# 0            NaN              NaN   NaN   NaN   NaN
# 1           38.0             17.2  -0.4   8.7 -14.8
# 2           35.0             13.7 -10.0  -6.5  -6.8
# 3           20.0             15.2  10.9  -9.7   4.2
# 4           35.1             24.3  17.7  13.1 -10.3
#
#    Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# 0               5.800000e+10                                 0.19
# 1               3.500000e+10                                 0.12
# ...

# %% [markdown]
# Местоположение появления метеорита с наибольшим количеством высвободившейся энергии.

# %%
df['Total Radiated Energy (J)'].idxmax()
df.loc[146,:]
# Out:
# Peak Brightness Date/Time (UT)         2013-02-15 03:20:33
# Latitude (deg.)                                      54.8N
# Longitude (deg.)                                     61.1E
# Altitude (km)                                         23.3
# Velocity (km/s)                                       18.6
# vx                                                    12.8
# vy                                                   -13.3
# vz                                                    -2.4
# Total Radiated Energy (J)                         3.75e+14
# Calculated Total Impact Energy (kt)                    440
# Name: 146, dtype: object

# %% [markdown]
# Определите метеорит с максимальной и минимальной скоростью.

# %%
df['Velocity (km/s)'].idxmax()
df.loc[67,:]
# Out:
# Peak Brightness Date/Time (UT)         2015-07-04 01:40:11
# Latitude (deg.)                                      38.6N
# Longitude (deg.)                                    103.1E
# Altitude (km)                                         46.3
# Velocity (km/s)                                         49
# vx                                                     0.9
# vy                                                   -40.4
# vz                                                   -27.7
# Total Radiated Energy (J)                          5.6e+10
# Calculated Total Impact Energy (kt)                   0.18
# Name: 67, dtype: object

# %%
df['Velocity (km/s)'].idxmin()
df.loc[300,:]
# Out:
# Peak Brightness Date/Time (UT)         2008-07-01 17:40:19
# Latitude (deg.)                                      37.1N
# Longitude (deg.)                                    115.7W
# Altitude (km)                                         36.1
# Velocity (km/s)                                        9.8
# vx                                                     2.8
# vy                                                     1.7
# vz                                                    -9.2
# Total Radiated Energy (J)                          3.6e+10
# Calculated Total Impact Energy (kt)                   0.12
# Name: 300, dtype: object

# %% [markdown]
# Определите время года, в которое вероятность появления метеоритов максимальна. Постройте график.

# %%
df1 = df
df1['mdate'] = df1 ['Peak Brightness Date/Time (UT)']
df1['mdate'] = pd.to_datetime(df1['mdate'])
df1['month'] = df1['mdate'].dt.month

# %%
# %matplotlib inline
df1['month'].value_counts()
# Out:
# 11    65
# 10    65
# 4     63
# 3     61
# 2     61
# 7     60
# 1     60
# 8     59
# 6     59
# 12    58
# 5     56
# 9     52
# Name: month, dtype: int64

# %%
df1.groupby(['month'])['month'].count().plot()

# %% [markdown]
#  Определите месяц года, для которого появление метеоритов наиболее вероятно (постройте необходимые графики).

# %%
df1 = df
df1['mdate'] = df1 ['Peak Brightness Date/Time (UT)']
df1['mdate'] = pd.to_datetime(df1['mdate'])
df1['year'] = df1['mdate'].dt.year
df1.groupby(['year'])['year'].count().plot()

# %% [markdown]
# Удалите строки данных, в которых для метеоритов не указана скорость. Выведите размер набора данных до и после удаления.

# %%
# До удаления
print(df.shape)
# Out:
# (719, 12)

# %%
df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2017-07-31 22:01:35           24.7N           118.5W
# 1              2017-07-23 06:12:38            6.6S            69.7W
# 2              2017-07-13 09:30:36           23.1N            60.7E
# 3              2017-06-30 14:26:45           34.3S           134.5E
# 4              2017-06-23 20:21:55           57.0N           143.7E
# 5              2017-06-20 13:41:32           54.2S           133.0E
# 6              2017-05-24 07:03:03            9.1S           101.8E
# 7              2017-05-22 17:44:39           49.6S           157.6W
# 8              2017-05-14 09:30:35           26.0S            32.4E
# 9              2017-04-30 21:28:28           25.7S            56.2E
# 10             2017-03-11 04:51:21           28.3N            60.2W
# 11             2017-03-09 04:16:37           40.5N            18.0W
# 12             2017-03-08 22:21:59           26.1S           174.9E
# ...

# %%
df[df['Velocity (km/s)'].notnull()].head()
# Out:
#   Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 1            2017-07-23 06:12:38            6.6S            69.7W
# 2            2017-07-13 09:30:36           23.1N            60.7E
# 3            2017-06-30 14:26:45           34.3S           134.5E
# 4            2017-06-23 20:21:55           57.0N           143.7E
# 5            2017-06-20 13:41:32           54.2S           133.0E
#
#    Altitude (km)  Velocity (km/s)    vx    vy    vz  \
# 1           38.0             17.2  -0.4   8.7 -14.8
# 2           35.0             13.7 -10.0  -6.5  -6.8
# 3           20.0             15.2  10.9  -9.7   4.2
# 4           35.1             24.3  17.7  13.1 -10.3
# 5           33.3             13.6   8.7  -5.7   8.8
#
#    Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# 1               3.500000e+10                                 0.12
# 2               7.300000e+10                                 0.23
# ...

# %%
# После удаления
df.groupby(['Velocity (km/s)']).count()
# Out:
#                  Peak Brightness Date/Time (UT)  Latitude (deg.)  \
# Velocity (km/s)
# 9.8                                           1                1
# 11.2                                          1                1
# 11.3                                          1                1
# 11.5                                          1                1
# 11.6                                          2                2
# 11.7                                          1                1
# 11.8                                          3                3
# 11.9                                          1                1
# 12.0                                          1                1
# 12.1                                          2                2
# 12.2                                          5                5
# 12.3                                          2                2
# 12.4                                          3                3
# ...

# %% [markdown]
# Построить график, на котором по оси ОХ отложено время суток, по OY – частота появления метеоритов

# %%
df1 = df
df1['mdate'] = df1 ['Peak Brightness Date/Time (UT)']
df1['mdate'] = pd.to_datetime(df1['mdate'])
df1['time'] = df1['mdate'].dt.hour
df1.groupby(['time'])['time'].count().plot()

# %% [markdown]
#  Вычислите корреляцию Пирсона и Спирмена между признаками Altitude и Total Radiated Energy. Сравните полученные величины корреляции. Постройте гистограммы для указанных признаков. Оцените значение p-value.

# %%
from scipy.stats import pearsonr
df=df[["Altitude (km)","Total Radiated Energy (J)"]].dropna()
pearsonr(df["Altitude (km)"],df["Total Radiated Energy (J)"]) #кореляция Пирсона
# Out:
# (-0.08578656525823587, 0.1336826987870989)

# %%
from scipy.stats import spearmanr
df=df[["Altitude (km)","Total Radiated Energy (J)"]].dropna()
spearmanr (df["Altitude (km)"],df["Total Radiated Energy (J)"]) #кореляция Спирмена
# Out:
# SpearmanrResult(correlation=-0.12671041939219074, pvalue=0.026415728610676672)

# %%
#Гистограмма для Altitude (km)
s = pd.Series(df["Altitude (km)"])
s.plot.hist()

# %%
#Гистограмма для Total Radiated Energy (J)
s = pd.Series(df["Total Radiated Energy (J)"])
s.plot.hist()
