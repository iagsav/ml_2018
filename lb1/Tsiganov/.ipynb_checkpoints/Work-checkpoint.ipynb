# %% [markdown]
# # Лабораторная 1
# ## Предварительная обработка данных
# ### Выполнил студент группы 16-В 1 Цыганов Никита
#
# <b>Цель лабораторной работы</b> – получение навыков работы с библиотеками анализа данных, предварительной обработки данных, средствами визуализации.
# <b>Задание:</b> 7 вариант - Камеры:
# 1. Визуализируйте корреляции между признаками, находящимися в наборе данных (heatmap). Сделайте выводы.
# 2. Вычислите корреляцию Пирсона и Спирмена между Price и Max (Min) Resolution. Сравните полученные величины корреляции. Постройте гистограммы для указанных признаков. Оцените значение p-value.
# 3. Постройте график изменения средней цены на камеры по годам.
# 4. Определите компанию, камеры которой наиболее часто встречаются в наборе данных.
# 5. Добавьте в набор данных признак, являющийся произведением двух других признаков.
# 6. Удалите строки с нулевыми значениями в данных. Выведите размер набора данных до и после удаления.
# 7. Определите камеру с максимальной стоимостью, определите камеру с минимальной стоимостью.
# 8. Определите год, в который было выпущено максимально количество новых камер.

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import seaborn as sns
from scipy import stats

file = pd.read_csv("camera_dataset.csv", ",")
file
# Out:
# c:\users\nekit\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
#                        Model Release date Max resolution Low resolution  \
# 0                     STRING       DOUBLE         DOUBLE         DOUBLE
# 1           Agfa ePhoto 1280         1997         1024.0          640.0
# 2           Agfa ePhoto 1680         1998         1280.0          640.0
# 3           Agfa ePhoto CL18         2000          640.0            0.0
# 4           Agfa ePhoto CL30         1999         1152.0          640.0
# 5     Agfa ePhoto CL30 Clik!         1999         1152.0          640.0
# 6           Agfa ePhoto CL45         2001         1600.0          640.0
# 7           Agfa ePhoto CL50         1999         1280.0          640.0
# 8        Canon PowerShot 350         1997          640.0            0.0
# 9        Canon PowerShot 600         1996          832.0          640.0
# 10       Canon PowerShot A10         2001         1280.0         1024.0
# 11      Canon PowerShot A100         2002         1280.0         1024.0
# 12       Canon PowerShot A20         2001         1600.0         1024.0
# 13      Canon PowerShot A200         2002         1600.0         1024.0
# 14       Canon PowerShot A30         2002         1280.0         1024.0
# 15      Canon PowerShot A300         2003         2048.0         1600.0
# 16      Canon PowerShot A310         2004         2048.0         1600.0
# 17       Canon PowerShot A40         2002         1600.0         1024.0
# 18      Canon PowerShot A400         2004         2048.0         1600.0
# 19      Canon PowerShot A410         2005         2048.0         1600.0
# 20      Canon PowerShot A420         2006         2272.0         1600.0
# 21      Canon PowerShot A430         2006         2272.0         1600.0
# 22      Canon PowerShot A450         2007         2592.0         2048.0
# 23      Canon PowerShot A460         2007         2592.0         2048.0
# 24        Canon PowerShot A5         1998         1024.0          512.0
# 25       Canon PowerShot A50         1999         1280.0          640.0
# 26      Canon PowerShot A510         2005         2048.0         1600.0
# 27      Canon PowerShot A520         2005         2272.0         1600.0
# 28      Canon PowerShot A530         2006         2592.0         2048.0
# 29      Canon PowerShot A540         2006         2816.0         2272.0
# ...                      ...          ...            ...            ...
# 1009       Sony Mavica FD-71         1998          640.0          320.0
# 1011               1.0              1.0                   580.0      138.0
# 1012               1.0              1.0                   580.0      140.0
# 1013               1.0              1.0                   580.0      142.0
# 1014               1.0              1.0                     0.0        0.0
# 1015               3.0              1.0                   630.0      143.0
# 1016               4.0              1.0                   600.0      142.0
# 1017               4.0              1.0                     0.0        0.0
# 1018               3.0              1.0                   660.0      126.0
# 1019               3.0              1.0                   900.0        0.0
# 1020               2.0              1.0                   990.0      126.0
# 1021              12.0              8.0                   205.0       91.0
# 1022              10.0              8.0                   320.0      116.0
# 1023              10.0             16.0                     0.0        0.0
# 1024              10.0             16.0                   230.0       93.0
# 1025               9.0              4.0                   290.0      123.0
# 1026               0.0              8.0                   240.0      116.0
# 1027               0.0              8.0                   240.0      116.0
# 1028               8.0              8.0                   320.0      105.0
# 1029              25.0              4.0                   380.0      122.0
# 1030              10.0              8.0                   290.0      112.0
# 1031              25.0              8.0                   350.0      130.0
# 1032               5.0              4.0                   320.0      121.0
# 1033               5.0              8.0                   310.0      123.0
# 1034              10.0              8.0                   320.0      120.0
# 1035               9.0             16.0                   390.0      116.0
# 1036              10.0              8.0                   340.0      107.0
# 1037              10.0             16.0                   340.0      107.0
# 1038              20.0              8.0                   180.0       86.0
#
#        Price
# 0     DOUBLE
# 1      179.0
# 2      179.0
# 3      179.0
# 4      269.0
# 5     1299.0
# 6      179.0
# 7      179.0
# 8      149.0
# 9      139.0
# 10     139.0
# 11     139.0
# 12     139.0
# 13     139.0
# 14     139.0
# 15     139.0
# 16     139.0
# 17     139.0
# 18     139.0
# 19     139.0
# 20     139.0
# 21     139.0
# 22     139.0
# 23     139.0
# 24     149.0
# 25     149.0
# 26     139.0
# 27     149.0
# 28     149.0
# 29     149.0
# ...      ...
# 1009  1399.0
# 1010  1399.0
# 1011  1399.0
# 1012  1399.0
# 1013  1399.0
# 1014  1399.0
# 1015  1399.0
# 1016  1399.0
# 1017  1399.0
# 1018  1399.0
# 1019  1399.0
# 1020  1399.0
# 1021   177.0
# 1022   177.0
# 1023   599.0
# 1024   177.0
# 1025    62.0
# 1026    62.0
# 1027   177.0
# 1028   177.0
# 1029    62.0
# 1030    62.0
# 1031    62.0
# 1032   449.0
# 1033    62.0
# 1034    62.0
# 1035    62.0
# 1036    62.0
# 1037    62.0
# 1038   129.0
#
# [1039 rows x 13 columns]

# %% [markdown]
# Проверяем, все ли столбцы содержат данные нужного формата:

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1039 entries, 0 to 1038
# Data columns (total 13 columns):
# Model                      1039 non-null object
# Release date               1039 non-null object
# Max resolution             1039 non-null object
# Low resolution             1039 non-null object
# Effective pixels           1039 non-null object
# Zoom wide (W)              1039 non-null object
# Zoom tele (T)              1039 non-null object
# Normal focus range         1039 non-null object
# Macro focus range          1038 non-null object
# Storage included           1037 non-null object
# Weight (inc. batteries)    1037 non-null object
# Dimensions                 1037 non-null object
# Price                      1039 non-null object
# dtypes: object(13)
# memory usage: 52.8+ KB

# %% [markdown]
# Так как в таблице все записи типа object(смешанный), необходимо сделать преобразование к нужным числовым типам:

# %%
file = file.drop([0])
file["Release date"] = file["Release date"].astype("int")
file["Max resolution"] = file["Max resolution"].astype("double")
file["Low resolution"] = file["Low resolution"].astype("double")
file["Effective pixels"] = file["Effective pixels"].astype("double")
file["Zoom wide (W)"] = file["Zoom wide (W)"].astype("double")
file["Zoom tele (T)"] = file["Zoom tele (T)"].astype("double")
file["Normal focus range"] = file["Normal focus range"].astype("double")
file["Macro focus range"] = file["Macro focus range"].astype("double")
file["Storage included"] = file["Storage included"].astype("double")
file["Weight (inc. batteries)"] = file["Weight (inc. batteries)"].astype("double")
file["Dimensions"] = file["Dimensions"].astype("double")
file["Price"] = file["Price"].astype("double")

# %% [markdown]
# 6. <b>Удалите строки с нулевыми значениями в данных. Выведите размер набора данных до и после удаления.</b>

# %%
print("Число записей в таблице до удаления: {0}".format(file.shape[0]))
un_null_file = file.copy()
un_null_file.replace(0.0, np.nan, inplace = True)
un_null_file.dropna(inplace = True)
print("Число записей в таблице после удаления: {0}".format(un_null_file.shape[0]))
# Out:
# Число записей в таблице до удаления: 1038
# Число записей в таблице после удаления: 773

# %% [markdown]
# 1. <b>Визуализируйте корреляции между признаками, находящимися в наборе данных (heatmap). Сделайте выводы.</b>

# %% [markdown]
# Визуализация будет создаваться с помощью библиотеки <b>seaborn</b>, так как в ней удобно строить такого рода таблицы. Таблица будет представлять из себя зависимость <b>средней цены</b> и <b>максимального разрешения</b> камер в этот же период за 11 лет.

# %%
table = un_null_file.pivot_table(index = "Release date",
                        columns = "Max resolution",
                        values = "Price",
                        aggfunc = "mean").fillna(0).applymap(float)
sns.heatmap(table, annot=True, fmt=".1f", linewidths=.10)

# %% [markdown]
# Из таблицы можно увидеть в каком году вообще было выпущено в продажу камеры с той или иной разрешающей способностью, когда определённое разрешение ушло с продаж и её средняя стоимость за этот же год.<br><br>
# Можно сделать вывод, что камеры с каждым годом становятся всё более продвинутыми, а их цена снижается, но при этом цена растёт по нарастающей в зависимости от разрешающей способности.

# %% [markdown]
# 2. <b>Вычислите корреляцию Пирсона и Спирмена между Price и Max (Min) Resolution. Сравните полученные величины корреляции. Постройте гистограммы для указанных признаков. Оцените значение p-value.</b>

# %%
# kor_max = un_null_file["Price"].corr(un_null_file["Max resolution"])
# kor_min = un_null_file["Price"].corr(un_null_file["Low resolution"])
kor_Pearson = stats.pearsonr(un_null_file["Price"], un_null_file["Max resolution"])
print("Критерий Пирсона: {0}. P-значение: {1};".format(kor_Pearson[0], kor_Pearson[1]))

kor_Spearman = stats.spearmanr(un_null_file["Price"],un_null_file["Max resolution"], nan_policy="omit") 
print("Критерий Спирмена: {0}. P-значение: {1}".format(kor_Spearman[0], kor_Spearman[1]))
# Out:
# Критерий Пирсона: -0.09515661977706802. P-значение: 0.008112393983706776;
# Критерий Спирмена: -0.03163061198225854. P-значение: 0.37982508301417606

# %% [markdown]
# При сравнении видно, что результаты различаются, но на небольшое значение. P-значение в случае с Пирсоном низкое, что говорит о том, что нулевая гипотеза - переменные линейно независимы - отвергается. Так как критерий отрицателен, то можно сказать, что величины обратно зависимы, т.е. чем выше значение одной переменной, тем ниже значение другой.

# %% [markdown]
# Гистограмма для Price:

# %%
sns.distplot(tuple(un_null_file["Price"].tolist()))
# Out:
# c:\users\nekit\appdata\local\programs\python\python37-32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Гистограмма для Max resolution:

# %%
sns.distplot(tuple(un_null_file["Max resolution"].tolist()))

# %% [markdown]
# 3. <b>Постройте график изменения средней цены на камеры по годам:</b>

# %%
un_null_file["Price"] = un_null_file["Price"][1:].astype(float)
data = un_null_file.groupby(["Release date"])["Price"].mean()
data
# Out:
# Release date
# 1998    382.533333
# 1999    309.818182
# 2000    403.400000
# 2001    557.972603
# 2002    475.042857
# 2003    351.538462
# 2004    370.840000
# 2005    326.981982
# 2006    250.741071
# 2007    280.038462
# Name: Price, dtype: float64

# %%
data.plot()

# %% [markdown]
# 4. <b>Определите компанию, камеры которой наиболее часто встречаются в наборе данных.</b>

# %%
list_firm = un_null_file["Model"].tolist()
list_firm = list(map(lambda firm: firm.split(" ")[0], list_firm))
list_firm
unique, pos = np.unique(list_firm, return_inverse=True)
counts = np.bincount(pos)
maxpos = counts.argmax()

print("Компания, камеры которой наиболее часто встречаются в наборе данных: {0} - {1} записи".format(unique[maxpos], counts[maxpos]))
# Out:
# Компания, камеры которой наиболее часто встречаются в наборе данных: Olympus - 102 записи

# %% [markdown]
# 5. <b>Добавьте в набор данных признак, являющийся произведением двух других признаков.</b>

# %% [markdown]
# В таблицу было добавлено поле "размер фото", полученный из произведения стобцов "максимальное разрешение" и "эффективные пиксели".

# %%
un_null_file["foto size"] = un_null_file["Max resolution"] * un_null_file["Effective pixels"]
un_null_file
# Out:
#                         Model  Release date  Max resolution  Low resolution  \
# 6            Agfa ePhoto CL45          2001          1600.0           640.0
# 10        Canon PowerShot A10          2001          1280.0          1024.0
# 11       Canon PowerShot A100          2002          1280.0          1024.0
# 12        Canon PowerShot A20          2001          1600.0          1024.0
# 13       Canon PowerShot A200          2002          1600.0          1024.0
# 14        Canon PowerShot A30          2002          1280.0          1024.0
# 15       Canon PowerShot A300          2003          2048.0          1600.0
# 17        Canon PowerShot A40          2002          1600.0          1024.0
# 20       Canon PowerShot A420          2006          2272.0          1600.0
# 21       Canon PowerShot A430          2006          2272.0          1600.0
# 22       Canon PowerShot A450          2007          2592.0          2048.0
# 23       Canon PowerShot A460          2007          2592.0          2048.0
# 25        Canon PowerShot A50          1999          1280.0           640.0
# 28       Canon PowerShot A530          2006          2592.0          2048.0
# 29       Canon PowerShot A540          2006          2816.0          2272.0
# 30       Canon PowerShot A550          2007          3072.0          2592.0
# 1002        89.0   149.0    21504.0
# 1003        91.0   149.0    21504.0
# 1004        91.0   429.0    26032.0
# 1008       142.0  1399.0     1600.0
# 1015       143.0  1399.0     1280.0
# 1016       142.0  1399.0     1280.0
# 1018       126.0  1399.0     1472.0
# 1020       126.0  1399.0     1600.0
# 1021        91.0   177.0     6144.0
# 1022       116.0   177.0     6144.0
# 1024        93.0   177.0    10240.0
# 1025       123.0    62.0     1280.0
# 1028       105.0   177.0     3458.0
# 1029       122.0    62.0     1280.0
# 1030       112.0    62.0     1600.0
# 1031       130.0    62.0     1600.0
# 1032       121.0   449.0     3584.0
# 1033       123.0    62.0     3584.0
# 1034       120.0    62.0     6144.0
# 1035       116.0    62.0     6144.0
# 1036       107.0    62.0     6144.0
# 1037       107.0    62.0     7200.0
# 1038        86.0   129.0     1600.0
#
# [773 rows x 14 columns]

# %% [markdown]
# 7. <b>Определите камеру с максимальной стоимостью, определите камеру с минимальной стоимостью.</b><br>
# <b>С максимальной стоимостью:</b>

# %%
un_null_file[un_null_file["Price"] == un_null_file["Price"].max()][["Model", "Price"]]
# Out:
#                 Model   Price
# 826  Ricoh GR Digital  4999.0
# 835    Ricoh RDC-i500  4999.0

# %% [markdown]
# <b>С минимальной стоимостью:</b>

# %%
un_null_file[un_null_file["Price"] == un_null_file["Price"].min()][["Model", "Price"]]
# Out:
#             Model  Price
# 348  JVC GC-QX3HD   14.0
# 349  JVC GC-QX5HD   14.0

# %% [markdown]
# 8. <b>Определите год, в который было выпущено максимально количество новых камер.</b>

# %%
un_null_file.groupby(["Release date", "Max resolution"])["Model"].count()
# Out:
# Release date  Max resolution
# 1998          1152.0             2
#               1280.0            12
#               1536.0             1
# 1999          1152.0             1
#               1280.0            13
#               1600.0            13
#               1712.0             1
#               1760.0             1
#               1792.0             2
#               1800.0             2
# 2000          1280.0             7
#               1368.0             1
#               1600.0            15
#               1760.0             2
#               1792.0             2
#               1856.0             2
#               2048.0            16
#               2160.0             1
#               2400.0             4
# 2001          1216.0             1
#               1280.0             9
#               1472.0             1
#               1600.0            21
#               1729.0             1
#               1792.0             1
#               1800.0             2
#               1856.0             1
#               1920.0             1
#               2032.0             2
#               2048.0            15
#                                 ..
# 2005          3840.0             2
# 2006          2272.0             3
#               2303.0             1
#               2304.0             1
#               2560.0             7
#               2576.0             2
#               2592.0             6
#               2800.0             2
#               2816.0            33
#               2832.0             1
#               2848.0             8
#               2864.0             2
#               3072.0            29
#               3264.0             9
#               3648.0             6
#               4224.0             2
# 2007          2560.0             1
#               2572.0             1
#               2592.0             2
#               2816.0             6
#               2848.0             3
#               3056.0             1
#               3072.0            49
#               3248.0             1
#               3254.0             1
#               3264.0            40
#               3296.0             4
#               3488.0             2
#               3648.0             9
#               4000.0            10
# Name: Model, Length: 129, dtype: int64

# %% [markdown]
# Из таблицы видно, что этот год - <b>2001</b>. 15 моделей с разрешением 2048 точек.
